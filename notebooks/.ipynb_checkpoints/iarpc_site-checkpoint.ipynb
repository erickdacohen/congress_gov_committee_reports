# %%
import os
import urllib
from pathlib import Path
import pandas as pd
from pyprojroot import here
import random
import requests
from bs4 import BeautifulSoup


headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

# %%
# Get the links from the performance elements tab from IARPC site. 

# url = r'https://www.iarpccollaborations.org/members/milestones/index.html' 
url = r'https://www.iarpccollaborations.org/members/milestones/research-goal/2670'

req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Sign in - IARPC
#   </title>
#   <!-- Info -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="Nmlc2_iqLPOKF1OjBkgzZDXFUD6_enqUGx1tjFkMhVM" name="google-site-verification"/>
#   <!-- Icons -->
#   <link href="/images/favicon.ico" rel="Shortcut Icon" type="image/x-icon"/>
#   <link href="/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="//cdn.jsdelivr.net/qtip2/2.2.0/jquery.qtip.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//ajax.googleapis.com/ajax/libs/jqueryui/1.10.3/themes/smoothness/jquery-ui.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <meta content="Interagency Arctic Research Policy Committee" name="author"/>
#   <meta content="Copyright (c) Interagency Arctic Research Policy Committee" name="Copyright"/>
#   <meta content="IARPC" name="apple-mobile-web-app-title"/>
# ...

# %%
import requests
# from requests.auth import HTTPBasicAuth
url = r'https://www.iarpccollaborations.org/members/tag-datasource.js.axd'
r = requests.get(url) #  auth=HTTPBasicAuth('ecohen@ida.org', 'mypassword')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-c45c34f1273f> in <module>
#       2 # from requests.auth import HTTPBasicAuth
#       3 url = r'https://www.iarpccollaborations.org/members/tag-datasource.js.axd'
# ----> 4 r = requests.get(url).json() #  auth=HTTPBasicAuth('myusername', 'mypassword')
#
# c:\users\ecohen\miniconda3\envs\kt\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# c:\users\ecohen\miniconda3\envs\kt\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
# ...

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head><title>
# 	Sign in - IARPC
# </title>
# <!-- Info -->
# <meta charset="utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta name="google-site-verification" content="Nmlc2_iqLPOKF1OjBkgzZDXFUD6_enqUGx1tjFkMhVM" />
#
# <!-- Icons -->
# <link href="/images/favicon.ico" rel="Shortcut Icon" type="image/x-icon" /><link href="/images/apple-touch-icon.png" rel="apple-touch-icon" />
# <link href='//cdn.jsdelivr.net/qtip2/2.2.0/jquery.qtip.min.css' media='all' rel='stylesheet' type='text/css' />
# <link href='//ajax.googleapis.com/ajax/libs/jqueryui/1.10.3/themes/smoothness/jquery-ui.min.css' media='all' rel='stylesheet' type='text/css' />
# <meta name="author" content="Interagency Arctic Research Policy Committee" />
# <meta name="Copyright" content="Copyright (c) Interagency Arctic Research Policy Committee" />
# <meta name="apple-mobile-web-app-title" content="IARPC" />
# <meta name="HandheldFriendly" content="true" />
# ...
